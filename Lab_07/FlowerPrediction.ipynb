# %%
import joblib
import warnings
warnings.filterwarnings('ignore')

# %%
loaded_model = joblib.load('iris_decision_tree.pk1')

# %%
prediction = loaded_model.predict([[7.2, 3.2, 4.7,1.4]])

# %%
flowers={
    0: "Setosa",
    1: "Versicolor",
    2: "virginica"
}

# %%
print(f"\nThis flower is {flowers[prediction[0]]}")
# Out:
# This flower is Versicolor
