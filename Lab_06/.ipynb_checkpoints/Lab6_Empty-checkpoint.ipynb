# %% [markdown]
# <a href='https://www.darshan.ac.in/'> <img src='https://www.darshan.ac.in/Content/media/DU_Logo.svg' width="250" height="300"/></a>
# <pre>
# <center><b><h1>Machine Learning & Deep Learning</b></center>
#
# <center><b><h1>Lab - 6</b></center>
# <pre>

# %% [markdown]
# # SVR

# %% [markdown]
# # Importing the libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVR

# %% [markdown]
# # Read World bank CSV

# %%
df = pd.read_csv('WorldBank.csv')

# %%
df.head()
# Out:
#   Country Name Country Code                                     Indicator Name  ...        2018      2019  2020
# 0        India          IND                    Export value index (2000 = 100)  ...  766.360840       NaN   NaN
# 1        India          IND  Insurance and financial services (% of commerc...  ...    3.921611  3.438072   NaN
# 2        India          IND  Merchandise imports by the reporting economy, ...  ...    0.535419       NaN   NaN
# 3        India          IND            Food imports (% of merchandise imports)  ...    4.156488  4.248261   NaN
# 4        India          IND  Share of tariff lines with international peaks...  ...    9.111423       NaN   NaN
#
# [5 rows x 65 columns]

# %%
# Out:
#      Country Name Country Code  \
# 0           India          IND
# 1           India          IND
# 2           India          IND
# 3           India          IND
# 4           India          IND
# ...           ...          ...
# 1435        India          IND
# 1436        India          IND
# 1437        India          IND
# 1438        India          IND
# 1439        India          IND
#
#                                          Indicator Name        Indicator Code  \
# 0                       Export value index (2000 = 100)     TX.VAL.MRCH.XD.WD
# 1     Insurance and financial services (% of commerc...     TX.VAL.INSF.ZS.WT
# 2     Merchandise imports by the reporting economy, ...     TM.VAL.MRCH.RS.ZS
# 3               Food imports (% of merchandise imports)     TM.VAL.FOOD.ZS.UN
# 4     Share of tariff lines with international peaks...     TM.TAX.MRCH.IP.ZS
# ...                                                 ...                   ...
# 1435  Foreign direct investment, net inflows (% of GDP)  BX.KLT.DINV.WD.GD.ZS
# 1436             Net capital account (BoP, current US$)        BN.TRF.KOGT.CD
# 1437        Travel services (% of service imports, BoP)        BM.GSR.TRVL.ZS
# 1438                    Cereal production (metric tons)        AG.PRD.CREL.MT
# 1439                       Arable land (% of land area)        AG.LND.ARBL.ZS
#
#           1960          1961          1962          1963          1964  \
# 0          NaN           NaN           NaN           NaN           NaN
# 1          NaN           NaN           NaN           NaN           NaN
# 2     4.983551  6.488050e+00  1.012461e+01  9.451370e+00  1.052948e+01
# 3          NaN           NaN  1.708001e+01  1.519791e+01  1.686304e+01
# 4          NaN           NaN           NaN           NaN           NaN
# ...        ...           ...           ...           ...           ...
# 1435       NaN           NaN           NaN           NaN           NaN
# 1436       NaN           NaN           NaN           NaN           NaN
# 1437       NaN           NaN           NaN           NaN           NaN
# 1438       NaN  8.737650e+07  8.725755e+07  9.037301e+07  9.370600e+07
# 1439       NaN  5.240365e+01  5.270433e+01  5.296332e+01  5.305144e+01
#
#               1965  ...          2011          2012          2013  \
# 0              NaN  ...  7.147485e+02  7.004085e+02  7.429281e+02
# 1              NaN  ...  6.403614e+00  5.246771e+00  5.729495e+00
# 2     1.089112e+01  ...  7.550664e-01  2.738416e-01  4.409538e-01
# 3     2.200813e+01  ...  3.741041e+00  4.048246e+00  3.895215e+00
# 4              NaN  ...  8.434346e+00  8.641136e+00  8.576307e+00
# ...            ...  ...           ...           ...           ...
# 1435           NaN  ...  2.002065e+00  1.312934e+00  1.516276e+00
# 1436           NaN  ...  6.791581e+07 -5.972328e+08  9.618297e+08
# 1437           NaN  ...  1.761773e+01  1.544257e+01  1.475397e+01
# 1438  7.969950e+07  ...  2.878600e+08  2.932900e+08  2.949095e+08
# 1439  5.321422e+01  ...  5.279817e+01  5.265254e+01  5.261756e+01
#
#               2014          2015          2016          2017          2018  \
# 0     7.614417e+02  6.322694e+02  6.242250e+02  7.061028e+02  7.663608e+02
# 1     5.060904e+00  4.706801e+00  4.471147e+00  3.760466e+00  3.921611e+00
# 2     1.514439e+00  2.228351e+00  2.270593e+00  1.770314e+00  5.354193e-01
# 3     4.458509e+00  5.758038e+00  6.505293e+00  6.137617e+00  4.156488e+00
# 4              NaN  5.802677e+00  7.707811e+00  8.288774e+00  9.111423e+00
# ...            ...           ...           ...           ...           ...
# 1435  1.695659e+00  2.092116e+00  1.937363e+00  1.506588e+00  1.552336e+00
# 1436 -7.433364e+07  3.706943e+07  1.368359e+08  3.731153e+07 -1.231007e+08
# 1437  1.799216e+01  1.795378e+01  1.707263e+01  1.686302e+01  1.716750e+01
# 1438  2.960100e+08  2.843330e+08  2.978500e+08  3.136100e+08           NaN
# 1439  5.262462e+01  5.262462e+01  5.262462e+01           NaN           NaN
#
#               2019  2020
# 0              NaN   NaN
# 1     3.438072e+00   NaN
# 2              NaN   NaN
# 3     4.248261e+00   NaN
# 4              NaN   NaN
# ...            ...   ...
# 1435  1.760283e+00   NaN
# 1436 -1.155591e+09   NaN
# 1437  1.755462e+01   NaN
# 1438           NaN   NaN
# 1439           NaN   NaN
#
# [1440 rows x 65 columns]

# %% [markdown]
# # Perform conditional selection to find - Population ages 15-64 (% of total population)

# %%
data = df[df['Indicator Name'] == 'Population ages 15-64 (% of total population)']

data.head()
india = data[data['Country Name'] == 'India']

india
# Out:
#   Country Name Country Code                                 Indicator Name  ...       2018       2019  2020
# 9        India          IND  Population ages 15-64 (% of total population)  ...  66.766743  67.003811   NaN
#
# [1 rows x 65 columns]

# %% [markdown]
# # Divide the data into input and output

# %%
X = india.columns[4:].astype(int).values.reshape(-1,1)

y = india.iloc[0,4:].values

# %%
X
# Out:
# array([[1960],
#        [1961],
#        [1962],
#        [1963],
#        [1964],
#        [1965],
#        [1966],
#        [1967],
#        [1968],
#        [1969],
#        [1970],
#        [1971],
#        [1972],
#        [1973],
#        [1974],
#        [1975],
#        [1976],
#        [1977],
#        [1978],
#        [1979],
#        [1980],
#        [1981],
#        [1982],
#        [1983],
#        [1984],
#        [1985],
#        [1986],
#        [1987],
#        [1988],
#        [1989],
#        [1990],
#        [1991],
#        [1992],
#        [1993],
#        [1994],
#        [1995],
#        [1996],
#        [1997],
#        [1998],
#        [1999],
#        [2000],
#        [2001],
#        [2002],
#        [2003],
#        [2004],
#        [2005],
#        [2006],
#        [2007],
#        [2008],
#        [2009],
#        [2010],
#        [2011],
#        [2012],
#        [2013],
#        [2014],
#        [2015],
#        [2016],
#        [2017],
#        [2018],
#        [2019],
#        [2020]])

# %%
y
# Out:
# array([np.float64(56.49748004), np.float64(56.17753236),
#        np.float64(55.80745463), np.float64(55.46166361),
#        np.float64(55.24893881), np.float64(55.21135053),
#        np.float64(55.09090078), np.float64(55.15534672),
#        np.float64(55.34507283), np.float64(55.57014408),
#        np.float64(55.78194745), np.float64(55.85676846),
#        np.float64(55.95268174), np.float64(56.07247186),
#        np.float64(56.23447551), np.float64(56.44405309),
#        np.float64(56.49722595), np.float64(56.62068516),
#        np.float64(56.78900152), np.float64(56.9691436),
#        np.float64(57.1425581), np.float64(57.18105454),
#        np.float64(57.22630775), np.float64(57.28875038),
#        np.float64(57.39054366), np.float64(57.54142108),
#        np.float64(57.55350984), np.float64(57.6545119),
#        np.float64(57.81875323), np.float64(58.01501187),
#        np.float64(58.22990246), np.float64(58.37403848),
#        np.float64(58.5472698), np.float64(58.75605047),
#        np.float64(59.012126), np.float64(59.31657719),
#        np.float64(59.56507329), np.float64(59.8572303),
#        np.float64(60.18600058), np.float64(60.53971518),
#        np.float64(60.90862046), np.float64(61.18898716),
#        np.float64(61.4993847), np.float64(61.83084479),
#        np.float64(62.173897), np.float64(62.52276485),
#        np.float64(62.80842981), np.float64(63.10261029),
#        np.float64(63.40924784), np.float64(63.74196691),
#        np.float64(64.10821053), np.float64(64.429404),
#        np.float64(64.80551944), np.float64(65.20848906),
#        np.float64(65.5959799), np.float64(65.94416405),
#        np.float64(66.27426247), np.float64(66.53818711),
#        np.float64(66.7667425), np.float64(67.00381119), np.float64(nan)],
#       dtype=object)

# %%
# Out:
# array([[56.49748004],
#        [56.17753236],
#        [55.80745463],
#        [55.46166361],
#        [55.24893881],
#        [55.21135053],
#        [55.09090078],
#        [55.15534672],
#        [55.34507283],
#        [55.57014408],
#        [55.78194745],
#        [55.85676846],
#        [55.95268174],
#        [56.07247186],
#        [56.23447551],
#        [56.44405309],
#        [56.49722595],
#        [56.62068516],
#        [56.78900152],
#        [56.9691436],
#        [57.1425581],
#        [57.18105454],
#        [57.22630775],
#        [57.28875038],
#        [57.39054366],
#        [57.54142108],
#        [57.55350984],
#        [57.6545119],
#        [57.81875323],
#        [58.01501187],
#        [58.22990246],
#        [58.37403848],
#        [58.5472698],
#        [58.75605047],
#        [59.012126],
#        [59.31657719],
#        [59.56507329],
#        [59.8572303],
#        [60.18600058],
#        [60.53971518],
#        [60.90862046],
#        [61.18898716],
#        [61.4993847],
#        [61.83084479],
#        [62.173897],
#        [62.52276485],
#        [62.80842981],
#        [63.10261029],
#        [63.40924784],
#        [63.74196691],
#        [64.10821053],
#        [64.429404],
#        [64.80551944],
#        [65.20848906],
#        [65.5959799],
#        [65.94416405],
#        [66.27426247],
#        [66.53818711],
#        [66.7667425],
#        [67.00381119]], dtype=object)

# %% [markdown]
# # Plot scatter plot of Population ages 15-64 (% of total population)

# %%
plt.scatter(X,y)

# %% [markdown]
# # Feature Scaling (Mandatory for SVR)**
# SVR is highly sensitive to the range of data points. If we don't scale (normalize) the data, the model will fail to find the correct hyperplane.

# %%
sc_X = StandardScaler()
sc_y = StandardScaler()

X_train = sc_X.fit_transform(X_train)
X_test = sc_X.transform(X_test)

y_train = sc_y.fit_transform(y_train.reshape(-1,1))

# %%
# Out:
# Scaling Complete.

# %% [markdown]
# # Splitting the dataset into the Training set and Test set

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2,random_state=0)

# %% [markdown]
# # Fitting SVR on 3 Different Kernel on dataset

# %%
svr_linear = SVR(kernel='linear')

svr_linear.fit(X_train,y_train.ravel())
# Out:
# SVR(kernel='linear')

# %%
svr_poly = SVR(kernel='poly',degree=3)

svr_poly.fit(X_train,y_train.ravel())
# Out:
# SVR(kernel='poly')

# %%
svr_rbf = SVR(kernel='rbf')

svr_rbf.fit(X_train,y_train.ravel())
# Out:
# SVR()

# %% [markdown]
# # Predict the x_test using 3 Kernel

# %%
y_pred_linear = svr_linear.predict(X_test)

# %%
y_pred_poly = svr_poly.predict(X_test)

# %%
y_pred_rbf = svr_rbf.predict(X_test)

# %% [markdown]
# # Visualising the  results

# %%
plt.scatter(X, y, color='red', label='Actual Date')

plt.plot(X,sc_y.inverse_transform(svr_linear.predict(sc_X.transform(X)).reshape(-1,1)),color='grey',label='linear Kernel')

# %%
plt.scatter(X, y, color='red', label='Actual Date')

plt.plot(X,sc_y.inverse_transform(svr_poly.predict(sc_X.transform(X)).reshape(-1,1)),color='grey',label='poly Kernel')

# %%
plt.scatter(X, y, color='red', label='Actual Date')

plt.plot(X,sc_y.inverse_transform(svr_rbf.predict(sc_X.transform(X)).reshape(-1,1)),color='grey',label='rbf Kernel')

# %% [markdown]
# ### **Student Activity : Prediction**
# **Task:** Predict the value for the Year **2025** (or value 6.5 in the demo data).
# Remember: You must transform the input before predicting, and inverse transform the output.

# %%
# Out:
# The predicted value for input 2025 is: 66.47
